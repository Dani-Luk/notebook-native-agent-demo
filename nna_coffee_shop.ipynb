# %%
from notebook_native_agent import start_agent, stop_agent, agent_status, agent_symbols, pause_agent, resume_agent, get_state

start_agent()
# Out:
#     <div id='auto-agent-welcome-9cdc87054b504e489e305d4a66eabaee' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;
#                 border:1px solid #e5e7eb;border-radius:22px;padding:22px 22px 18px 22px;
#                 background:linear-gradient(180deg,#ffffff 0%,#fbfbfc 100%);
#                 box-shadow:0 10px 30px rgba(17,24,39,0.05);color:#111827;'>
#
#
#     <style>
#       #auto-agent-welcome-9cdc87054b504e489e305d4a66eabaee .auto-agent-example-card {
#         position: relative;
#         border: 1px solid #e5e7eb;
#         border-radius: 14px;
#         padding: 11px 82px 11px 14px;
#         background: linear-gradient(180deg,#ffffff 0%,#fafafa 100%);
#         box-shadow: 0 1px 1px rgba(0,0,0,0.02);
#       }
#
#       #auto-agent-welcome-9cdc87054b504e489e305d4a66eabaee .auto-agent-example-text {
#         font-family: ui-monospace,SFMono-Regular,Menlo,monospace;
#         font-size: 14px;
#         line-height: 1.45;
# ...

# %%
Create a fake coffee shop dataset and reveal the best-selling drinks with charts
# Out:
#     <div id='auto-agent-ed59e493a05940c8af066f482cfeadf6' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;border:1px solid #ddd;border-radius:16px;padding:16px;background:white;box-shadow:0 1px 2px rgba(0,0,0,0.04);'>
#       <style>
#         #auto-agent-ed59e493a05940c8af066f482cfeadf6 .auto-agent-code-wrap {
#           position: relative;
#           margin-bottom: 12px;
#           background: #0b1020;
#           border: 1px solid #1f2937;
#           border-radius: 12px;
#           overflow: hidden;
#         }
#         #auto-agent-ed59e493a05940c8af066f482cfeadf6 .auto-agent-code-toolbar {
#           display: flex;
#           justify-content: flex-end;
#           align-items: center;
#           padding: 8px 10px;
#           background: #111827;
#           border-bottom: 1px solid #1f2937;
#         }
#         #auto-agent-ed59e493a05940c8af066f482cfeadf6 .auto-agent-copy-btn {
#           border: 1px solid #374151;
# ...

# %%
Show me the best-selling drinks by time of day: morning, afternoon, evening.
# Out:
#     <div id='auto-agent-82b46e115f774fa79d891dcde8e359b7' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;border:1px solid #ddd;border-radius:16px;padding:16px;background:white;box-shadow:0 1px 2px rgba(0,0,0,0.04);'>
#       <style>
#         #auto-agent-82b46e115f774fa79d891dcde8e359b7 .auto-agent-code-wrap {
#           position: relative;
#           margin-bottom: 12px;
#           background: #0b1020;
#           border: 1px solid #1f2937;
#           border-radius: 12px;
#           overflow: hidden;
#         }
#         #auto-agent-82b46e115f774fa79d891dcde8e359b7 .auto-agent-code-toolbar {
#           display: flex;
#           justify-content: flex-end;
#           align-items: center;
#           padding: 8px 10px;
#           background: #111827;
#           border-bottom: 1px solid #1f2937;
#         }
#         #auto-agent-82b46e115f774fa79d891dcde8e359b7 .auto-agent-copy-btn {
#           border: 1px solid #374151;
# ...

# %%
Create a mini business dashboard: KPIs, top drinks, revenue trend, category mix.
# Out:
#     <div id='auto-agent-56e28f247e734f589551692cb42814ed' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;border:1px solid #ddd;border-radius:16px;padding:16px;background:white;box-shadow:0 1px 2px rgba(0,0,0,0.04);'>
#       <style>
#         #auto-agent-56e28f247e734f589551692cb42814ed .auto-agent-code-wrap {
#           position: relative;
#           margin-bottom: 12px;
#           background: #0b1020;
#           border: 1px solid #1f2937;
#           border-radius: 12px;
#           overflow: hidden;
#         }
#         #auto-agent-56e28f247e734f589551692cb42814ed .auto-agent-code-toolbar {
#           display: flex;
#           justify-content: flex-end;
#           align-items: center;
#           padding: 8px 10px;
#           background: #111827;
#           border-bottom: 1px solid #1f2937;
#         }
#         #auto-agent-56e28f247e734f589551692cb42814ed .auto-agent-copy-btn {
#           border: 1px solid #374151;
# ...
