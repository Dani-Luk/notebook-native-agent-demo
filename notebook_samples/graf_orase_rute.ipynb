# %%
from notebook_native_agent import start_agent, stop_agent, agent_status, agent_symbols, pause_agent, resume_agent, get_state

start_agent()
# Out:
#     <div id='auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;
#                 border:1px solid #e5e7eb;border-radius:22px;padding:22px 22px 18px 22px;
#                 background:linear-gradient(180deg,#ffffff 0%,#fbfbfc 100%);
#                 box-shadow:0 10px 30px rgba(17,24,39,0.05);color:#111827;'>
#
#
#     <style>
#       #auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac .auto-agent-example-card {
#         position: relative;
#         border: 1px solid #e5e7eb;
#         border-radius: 14px;
#         padding: 11px 82px 11px 14px;
#         background: linear-gradient(180deg,#ffffff 0%,#fafafa 100%);
#         box-shadow: 0 1px 1px rgba(0,0,0,0.02);
#       }
#
#       #auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac .auto-agent-example-text {
#         font-family: ui-monospace,SFMono-Regular,Menlo,monospace;
#         font-size: 14px;
#         line-height: 1.45;
#         color: #111827;
#         white-space: pre-wrap;
#       }
#
#       #auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac .auto-agent-copy-btn {
#         position: absolute;
#         top: 8px;
#         right: 10px;
#         border: 1px solid #d1d5db;
#         background: #ffffff;
#         color: #374151;
#         border-radius: 8px;
#         padding: 4px 8px;
#         font-size: 12px;
#         cursor: pointer;
#         line-height: 1.2;
#       }
#
#       #auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac .auto-agent-copy-btn:hover {
#         background: #f3f4f6;
#       }
#
#     </style>
#
#     <script>
#       (function() {
#         const root = document.getElementById('auto-agent-welcome-a8c3769a17444bb6aa76aa931c0cf5ac');
#         if (!root || root.dataset.copyReady === '1') return;
#         root.dataset.copyReady = '1';
#
#         async function copyText(text) {
#           try {
#             if (navigator.clipboard && navigator.clipboard.writeText) {
#               await navigator.clipboard.writeText(text);
#               return true;
#             }
#           } catch (err) {
#             // Kaggle may block Clipboard API via iframe permissions policy.
#           }
#
#           try {
#             const ta = document.createElement('textarea');
#             ta.value = text;
#             ta.setAttribute('readonly', '');
#             ta.style.position = 'fixed';
#             ta.style.left = '-9999px';
#             ta.style.top = '0';
#             document.body.appendChild(ta);
#             ta.focus();
#             ta.select();
#
#             const ok = document.execCommand('copy');
#             ta.remove();
#             return ok;
#           } catch (err) {
#             return false;
#           }
#         }
#
#         root.addEventListener('click', async function(event) {
#           const btn = event.target.closest('.auto-agent-copy-btn');
#           if (!btn || !root.contains(btn)) return;
#
#           const targetId = btn.getAttribute('data-copy-target');
#           const textEl = targetId ? document.getElementById(targetId) : null;
#           if (!textEl) return;
#
#           const text = textEl.innerText || textEl.textContent || '';
#           const old = btn.innerText;
#
#           const ok = await copyText(text);
#           btn.innerText = ok ? '✓ copied' : 'copy failed';
#           setTimeout(() => btn.innerText = old, 1200);
#         });
#       })();
#     </script>
#
#
#       <div style='display:flex;justify-content:space-between;gap:16px;align-items:flex-start;flex-wrap:wrap;margin-bottom:16px;'>
#         <div style='min-width:280px;flex:1 1 380px;'>
#           <div style='display:inline-flex;align-items:center;gap:8px;
#                       padding:6px 10px;border-radius:999px;border:1px solid #dbeafe;
#                       background:#eff6ff;color:#1d4ed8;font-size:12px;font-weight:700;
#                       letter-spacing:.02em;margin-bottom:12px;'>
#             <span>⚡</span>
#             <span>Notebook agent active</span>
#           </div>
#           <div style='font-size:20px;font-weight:800;line-height:1.2;margin-bottom:8px;'>
#             Notebook Native Agent
#           </div>
#           <div style='font-size:14px;line-height:1.5;color:#4b5563;max-width:760px;'>
#             Write Python normally, or write a natural-language request in a cell.
#             The agent shares the live notebook context, proposes code, and can safely auto-run allowed cases.
#           </div>
#         </div>
#
#         <div style='display:flex;gap:8px;flex-wrap:nowrap;justify-content:flex-end;flex:0 1 520px;'>
#           <span style='display:inline-flex;gap:6px;align-items:center;padding:6px 10px;border-radius:999px;border:1px solid #bfdbfe;background:#eff6ff;color:#1d4ed8;font-size:12px;font-weight:600;'><span style='opacity:.8'>provider:</span><span>openai</span></span>
#           <span style='display:inline-flex;gap:6px;align-items:center;padding:6px 10px;border-radius:999px;border:1px solid #a7f3d0;background:#ecfdf5;color:#065f46;font-size:12px;font-weight:600;'><span style='opacity:.8'>auto-execute:</span><span>on</span></span>
#           <span style='display:inline-flex;gap:6px;align-items:center;padding:6px 10px;border-radius:999px;border:1px solid #a7f3d0;background:#ecfdf5;color:#065f46;font-size:12px;font-weight:600;'><span style='opacity:.8'>fallback:</span><span>on</span></span>
#           <span style='display:inline-flex;gap:6px;align-items:center;padding:6px 10px;border-radius:999px;border:1px solid #d1d5db;background:#f3f4f6;color:#111827;font-size:12px;font-weight:600;'><span style='opacity:.8'>LLM cell classifier:</span><span>off</span></span>
#         </div>
#       </div>
#
#       <div style='display:grid;grid-template-columns:minmax(320px,1.15fr) minmax(260px,.85fr);gap:16px;align-items:start;'>
#         <div style='border:1px solid #e5e7eb;border-radius:18px;padding:16px;background:#ffffff;'>
#           <div style='font-size:15px;font-weight:800;margin-bottom:10px;'>Try a natural-language cell like:</div>
#           <div style='display:grid;gap:10px;'>
#
#     <div class='auto-agent-example-card'>
#       <div id='auto-agent-example-a8a322d68a02494fbe1668dce4566554' class='auto-agent-example-text'>show me a funny fractal</div>
#       <button
#         class='auto-agent-copy-btn'
#         type='button'
#         data-copy-target='auto-agent-example-a8a322d68a02494fbe1668dce4566554'
#         title='Copy example prompt'
#       >⧉ copy</button>
#     </div>
#
#
#     <div class='auto-agent-example-card'>
#       <div id='auto-agent-example-9738ff8bf794485e8af79750214bb79e' class='auto-agent-example-text'>plot this: z = sin(x) * cos(y) (use plotly)</div>
#       <button
#         class='auto-agent-copy-btn'
#         type='button'
#         data-copy-target='auto-agent-example-9738ff8bf794485e8af79750214bb79e'
#         title='Copy example prompt'
#       >⧉ copy</button>
#     </div>
#
#
#     <div class='auto-agent-example-card'>
#       <div id='auto-agent-example-4c4be21739824328aa61e70b20cf2770' class='auto-agent-example-text'>I have this: tips.csv</div>
#       <button
#         class='auto-agent-copy-btn'
#         type='button'
#         data-copy-target='auto-agent-example-4c4be21739824328aa61e70b20cf2770'
#         title='Copy example prompt'
#       >⧉ copy</button>
#     </div>
#
#           </div>
#         </div>
#
#         <div style='display:grid;gap:12px;'>
#           <div style='border:1px solid #e5e7eb;border-radius:18px;padding:16px;background:#ffffff;'>
#             <div style='font-size:15px;font-weight:800;margin-bottom:10px;'>How it works</div>
#             <div style='display:grid;gap:10px;'>
#               <div style='display:flex;gap:10px;align-items:flex-start;'>
#                 <div style='width:24px;height:24px;border-radius:999px;background:#111827;color:white;font-size:12px;font-weight:700;display:flex;align-items:center;justify-content:center;flex:0 0 24px;'>1</div>
#                 <div style='font-size:14px;color:#374151;line-height:1.45;'><b>Stay in the notebook</b> — write Python or natural-language requests directly in code cells; the router turns non-Python

# %%
Fa un graf cu orașe și rute, si apoi afiseaza cele mai scurte rute dintr-un oraș
# Out:
#     <div id='auto-agent-d1edd96d512a4057a301287d35d34eb6' style='font-family:system-ui,-apple-system,Segoe UI,Roboto,sans-serif;border:1px solid #ddd;border-radius:16px;padding:16px;background:white;box-shadow:0 1px 2px rgba(0,0,0,0.04);'>
#       <style>
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-code-wrap {
#           position: relative;
#           margin-bottom: 12px;
#           background: #0b1020;
#           border: 1px solid #1f2937;
#           border-radius: 12px;
#           overflow: hidden;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-code-toolbar {
#           display: flex;
#           justify-content: flex-end;
#           align-items: center;
#           padding: 8px 10px;
#           background: #111827;
#           border-bottom: 1px solid #1f2937;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-copy-btn {
#           border: 1px solid #374151;
#           background: #111827;
#           color: #e5e7eb;
#           border-radius: 8px;
#           padding: 4px 9px;
#           font-size: 13px;
#           cursor: pointer;
#           line-height: 1.2;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-copy-btn:hover {
#           background: #1f2937;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-code {
#           margin: 0;
#           padding: 14px 16px;
#           overflow-x: auto;
#           background: #0b1020;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-code pre {
#           margin: 0;
#           white-space: pre-wrap;
#           word-break: break-word;
#           font-size: 13px;
#           line-height: 1.5;
#           background: transparent;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-code-fallback {
#           margin: 0;
#           padding: 14px 16px;
#           white-space: pre-wrap;
#           word-break: break-word;
#           background: #0b1020;
#           color: #e5e7eb;
#           font-size: 13px;
#           line-height: 1.5;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 #auto-agent-d1edd96d512a4057a301287d35d34eb6-context p:first-child {
#           margin-top: 0;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 #auto-agent-d1edd96d512a4057a301287d35d34eb6-context p:last-child {
#           margin-bottom: 0;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 #auto-agent-d1edd96d512a4057a301287d35d34eb6-context ul,
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 #auto-agent-d1edd96d512a4057a301287d35d34eb6-context ol {
#           margin: 0.35rem 0 0.35rem 1.2rem;
#           padding-left: 1rem;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 #auto-agent-d1edd96d512a4057a301287d35d34eb6-context code {
#           background: #e5e7eb;
#           border-radius: 4px;
#           padding: 0 4px;
#           font-size: 0.95em;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-markdown p:first-child {
#           margin-top: 0;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-markdown p:last-child {
#           margin-bottom: 0;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-markdown ul,
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-markdown ol {
#           margin: 0.35rem 0 0.35rem 1.2rem;
#           padding-left: 1rem;
#         }
#         #auto-agent-d1edd96d512a4057a301287d35d34eb6 .auto-agent-markdown code {
#           background: #e5e7eb;
#           border-radius: 4px;
#           padding: 0 4px;
#           font-size: 0.95em;
#         }
#       </style>
#       <div style='font-size:20px;font-weight:800;margin-bottom:12px;color:#111827;'>Notebook Native Agent</div>
#       <div style='font-weight:700;margin-bottom:6px;color:#111827;'>What I understood</div>
#       <div style='margin-bottom:12px;color:#111827;'>Creez un graf cu orașe și rute și afișez cele mai scurte drumuri dintr-un oraș ales.</div>
#
#       <div style='font-weight:700;margin-bottom:6px;color:#111827;'>Proposed solution</div>
#       <div class='auto-agent-markdown auto-agent-solution' style='margin-bottom:12px;color:#111827;'>
#         <p>Voi construi un exemplu de rețea de orașe și rute ponderate cu distanțe, apoi:</p>
# <ol>
# <li>creez graful <code>cities_graph</code> din <code>routes_df</code></li>
# <li>desenez graful și evidențiez orașul de pornire <code>start_city</code></li>
# <li>calculez cele mai scurte rute către toate celelalte orașe</li>
# <li>afișez rezultatul într-un tabel <code>shortest_paths_df</code></li>
# </ol>
# <p><strong>Presupunere vizibilă:</strong> fiindcă orașul de start nu a fost specificat, folosesc implicit <code>start_city = "București"</code>, pe care îl poți schimba ușor ulterior.</p>
# <p>Simboluri reutilizabile create: <code>routes_df</code>, <code>cities_graph</code>, <code>start_city</code>, <code>shortest_paths_df</code>.</p>
#       </div>
#       <div style='font-weight:700;margin-bottom:6px;color:#111827;'>Code preview</div>
#       <div class='auto-agent-code-wrap'>
#         <div class='auto-agent-code-toolbar'>
#           <button id='auto-agent-d1edd96d512a4057a301287d35d34eb6-copy' class='auto-agent-copy-btn' type='button'>⧉ copy</button>
#         </div>
#         <div id='auto-agent-d1edd96d512a4057a301287d35d34eb6-code'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .auto-agent-code .hll { background-color: #49483e }
# .auto-agent-code { background: #272822; color: #F8F8F2 }
# .auto-agent-code .c { color: #959077 } /* Comment */
# .auto-agent-code .err { color: #ED007E; background-color: #1E0010 } /* Error */
# .auto-agent-code .esc { color: #F8F8F2 } /* Escape */
# .auto-agent-code .g { color: #F8F8F2 } /* Generic */
# .auto-agent-code .k { color: #66D9EF } /* Keyword */
# .auto-agent-code .l { color: #AE81FF } /* Literal */
# .auto-agent-code .n { color: #F8F8F2 } /* Name */
# .auto-agent-code .o { color: #FF4689 } /* Operator */
# .auto-agent-code .x { color: #F8F8F2 } /* Other */
# .auto-agent-code .p { color: #F8F8F2 } /* Punctuation */
# .auto-agent-code .ch { color: #959077 } /* Comment.Hashbang */
# .auto-agent-code .cm { color: #959077 } /* Comment.Multiline */
# .auto-agent-code .cp { color: #959077 } /* Comment.Preproc */
# .auto-agent-code .cpf { color: #959077 } /* Comment.PreprocFile */
# .auto-agent-code .c1 { color: #959077 } /* Comment.Single */
# .auto-agent-code .cs { color: #959077 } /* Comment.Special */
# .auto-agent-code .gd { color: #FF4689 } /* Generic.Deleted */
# .auto-agent-code .ge { color: #F8F8F2; font-style: italic } /* Generic.Emph */
# .auto-agent-code .ges { color: #F8F8F2; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .auto-agent-code .gr { color: #F8F8F2 } /* Generic.Error */
# .auto-agent-code .gh { color: #F8F8F2 } /* Generic.Heading */
# .auto-agent-code .gi { color: #A6E22E } /* Generic.Inserted */
# .auto-agent-code .go { color: #66D9EF } /* Generic.Output */
# .auto-agent-code .gp { color: #FF4689; font-weight: bold } /* Generic.Prompt */
# .auto-agent-code .gs { color: #F8F8F2; font-weight: bold } /* Generic.Strong */
# .auto-agent-code .gu { color: #959077 } /* Generic.Subheading */
# .auto-agent-code .gt { color: #F8F8F2 } /* Generic.Traceback */
# .auto-agent-code .kc { color: #66D9EF } /* Keyword.Constant */
# .auto-agent-code .kd { color: #66D9EF } /* Keyword.Declaration */
# .auto-agent-code .kn { color: #FF4689 } /* Keyword.Namespace */
# .auto-agent-code .kp { color: #66D9EF } /* Keyword.Pseudo */
# .auto-agent-code .kr { color: #66D9EF } /* Keyword.Reserved */
# .auto-agent-code .kt { color: #66D9EF } /* Keyword.Type */
# .auto-agent-code .ld { color: #E6D
# Rute disponibile:
#          source       target  distance_km
# 0     București     Ploiești           60
# 1     București       Brașov          170
# 2     București    Constanța          225
# 3      Ploiești       Brașov          110
# 4      Ploiești        Buzău           95
# 5         Buzău         Iași          310
# 6        Brașov        Sibiu          145
# 7         Sibiu  Cluj-Napoca          170
# 8   Cluj-Napoca       Oradea          155
# 9        Brașov  Târgu Mureș          165
# 10  Târgu Mureș  Cluj-Napoca          100
# 11    Constanța       Galați          190
# 12       Galați         Iași          230
# 13    București      Craiova          210
# 14      Craiova        Sibiu          175
# 15      Craiova    Timișoara          290
# 16    Timișoara       Oradea          170
# Cele mai scurte rute din București:
#     destination  distance_km  \
# 0     București            0
# 1      Ploiești           60
# 2         Buzău          155
# 3        Brașov          170
# 4       Craiova          210
# 5     Constanța          225
# 6         Sibiu          315
# 7   Târgu Mureș          335
# 8        Galați          415
# 9   Cluj-Napoca          435
# 10         Iași          465
# 11    Timișoara          500
# 12       Oradea          590
#
#                                                  path  stops
# 0                                           București      0
# 1                               București -> Ploiești      1
# 2                      București -> Ploiești -> Buzău      2
# 3                                 București -> Brașov      1
# 4                                București -> Craiova      1
# 5                              București -> Constanța      1
# 6                        București -> Brașov -> Sibiu      2
# 7                  București -> Brașov -> Târgu Mureș      2
# 8                    București -> Constanța -> Galați      2
# 9   București -> Brașov -> Târgu Mureș -> Cluj-Napoca      3
# 10             București -> Ploiești -> Buzău -> Iași      3
# 11                  București -> Craiova -> Timișoara      2
# 12  București -> Brașov -> Târgu Mureș -> Cluj-Nap...      4
